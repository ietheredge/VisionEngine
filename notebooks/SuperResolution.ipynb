# %%
from ISR.models import RDN, RRDN

rdn = RDN(weights='noise-cancel')
rrdn = RRDN(weights='gans')

# rdn = RDN(weights='psnr-small')

# %%
import numpy as np
from PIL import Image

# %%
img = Image.open('/home/etheredge/Workspace/infoGAN/test_outputs_3_samples/00716.png')
lr_img = np.array(img)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F029DDEDE10>

# %%
sr_img = rdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F029DE1D190>

# %%
sr_img = rrdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F029DDED490>
